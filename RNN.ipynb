# %% [markdown]
# This notebook implements a simple recurrent neural network on Supreme Court oral arguments. The model attempts to predict the outcome of cases. It is a binary classification problem.

# %%
from google.colab import drive # Uncomment first time running notebook
drive.mount('/content/drive') # Uncomment first time running notebook
# !ls "/content/drive/Shareddrives/Advanced ML Project Spring 2021"
# Out:
# Mounted at /content/drive
#  01b_cnn_offline.ipynb			  'Mid-quarter presentation.gslides'
# '1 - Simple Sentiment Analysis.ipynb'	   naive_bayes.ipynb
# '2 - Upgraded Sentiment Analysis.ipynb'   'Nathan Lit Review.gdoc'
#  charlie_midterm_presentation_backup.mp4   notebooks
# 'Data sources.gdoc'			  'Project To-Do List.gdoc'
# 'Final presentation.gslides'		  'Proposal ideas.gdoc'
# 'Final report.gdoc'			  'Proposal (Rough Draft).gdoc'
#  intermediate_data			   raw_data
#  LSTM.ipynb				   scraped_data

# %%
import os
import urllib.request, json
import numpy as np
import pandas as pd
import torch

SHARED_DRIVE_BASE_FOLDER = "/content/drive/Shareddrives/Advanced ML Project Spring 2021/"
LABEL_VAR = 'partyWinning' # 'caseDisposition'
TEXT_VAR = 'text'
# BATCH_SIZE = 64 # batch size for training
BATCH_SIZE = 8 # batch size for training

# with open(SHARED_DRIVE_BASE_FOLDER + "intermediate_data/tuples_2017-2018.json") as fp:
#   tuple_list_2017_2018_data = json.load(fp)
# len(tuple_list_2017_2018_data)

# %%
import warnings   # being significantly revamped
import random
import numpy as np
import torch as T
import torchtext as tt
from torchtext.legacy import data

# device = T.device("cpu")
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
# Out:
# cuda

# %% [markdown]
# The cell below loads data into PyTorch Dataset objects, tokenizes the words, removes stop words, and splits into training, testing, and validation sets.

# %%
warnings.filterwarnings("ignore")  # else warnings spew
random.seed(2)
T.manual_seed(1)
np.random.seed(1)

print("\nBegin torchtext from raw data demo ")

print("\nCreating RAW, TEXT, LABEL Field objects ")
# RAW = tt.data.RawField()
RAW = data.RawField()
# TEXT = tt.data.Field(sequential=True,
TEXT = data.Field(sequential=True,
  init_token='',  # start of sequence
  eos_token='',   # end of sequence
  lower=True,
  tokenize=tt.data.utils.get_tokenizer("basic_english"),)
# LABEL = tt.data.Field(sequential=False,
LABEL = data.Field(sequential=False,
  use_vocab=False,
  unk_token=None,
  is_target=True,
  dtype=torch.float)

print("\nSplitting into train, valid, test ")
(train_obj, valid_obj, test_obj) = \
  data.TabularDataset.splits(
  # tt.data.TabularDataset.splits(
  path=".\\.data",
  # train='train.csv',
  train=SHARED_DRIVE_BASE_FOLDER + f"intermediate_data/train_balanced_2010-2018.csv",
  # validation='validation.csv',
  validation=SHARED_DRIVE_BASE_FOLDER + f"intermediate_data/validate_balanced_2010-2018.csv",
  # test='test.csv',
  test=SHARED_DRIVE_BASE_FOLDER + f"intermediate_data/test_balanced_2010-2018.csv",
  format='csv',
  skip_header=True,
  # fields=[('id', RAW), ('review', TEXT),
  #   ('label', LABEL)])
  fields=[('id', RAW), ('label', LABEL), ('text', TEXT)])

print("\nThe \'text\' field for item [2] is: ")
print(train_obj[2].text)

print("\nCreating vocabulary object ")
TEXT.build_vocab(train_obj, min_freq=50)
print("The idx of \'good\' is ",
  TEXT.vocab.stoi['good'])  # 13
print("The string value of 8 is ",
  TEXT.vocab.itos[8])  # 'bad'

LABEL.build_vocab(train_obj)
print("LABEL.vocab.stoi is " + str(LABEL.vocab.stoi))
 
print("\nCreating a train BucketIterator ")

# train_iter  = tt.data.BucketIterator(
train_iter = data.BucketIterator(
  dataset=train_obj,
  batch_size = 2,
  sort_key=lambda x: len(x.review),
  shuffle=True,
  device=device)

valid_iter = data.BucketIterator(
  dataset=valid_obj,
  batch_size = 2,
  sort_key=lambda x: len(x.review),
  shuffle=True,
  device=device)

test_iter = data.BucketIterator(
  dataset=test_obj,
  batch_size = 2,
  sort_key=lambda x: len(x.review),
  shuffle=True,
  device=device)
# print("train_obj")
# print(train_obj)
# print(next(train_obj))

print("\nIterating train data (batch_size=2) ")
# for item in iter(train_iter):
for item in train_iter:
  print("\n=====\n")
  print(item.id)
  print(item.text)
  print(item.label)
  
print("\nEnd of demo ")
# Out:
# Begin torchtext from raw data demo
#
# Creating RAW, TEXT, LABEL Field objects
#
# Splitting into train, valid, test
#
# The 'text' field for item [2] is:
# ['well', 'hear', 'argument', 'next', 'in', 'case', '121497', 'kellogg', 'brown', 'root', 'services', 'v', 'united', 'states', 'ex', 'rel', 'benjamin', 'carter', 'mr', 'elwood', 'mr', 'chief', 'justice', 'and', 'may', 'it', 'please', 'the', 'court', 'by', 'clearing', 'the', 'way', 'for', 'relator', 'to', 'file', 'a', 'fifth', 'identical', 'false', 'claims', 'act', 'complaint', 'against', 'kbr', 'raising', 'allegations', 'the', 'government', 'had', 'long', 'known', 'from', 'other', 'sources', 'the', 'court', 'below', 'erred', 'in', 'two', 'respects', 'first', 'the', 'plain', 'text', 'and', 'and', 'history', 'of', 'the', 'wartime', 'suspension', 'of', 'limitations', 'act', 'confirmed', 'that', 'it', 'applies', 'exclusively', 'to', 'crimes', 'the', 'language', 'of', 'the', 'provision', 'tolls', 'limitations', 'tolls', 'limitations', 'periods', 'for', 'offenses', 'at', 'the', 'on', 'the', 'very', 'day', 'that', 'that', 'provision', 'went', 'into', 'effect', 'a', 'neighboring', 'provision', 'a', 'nearby', 'provision', 'of', 'title', '18', 'divided', 'offenses', 'into', 'two', 'categories', 'felonies', 'and', 'misdemeanors', 'both', 'plainly', 'applying', 'to', 'crimes', 'a', 'neighboring', 'provision', 'also', 'of', 'title', '18', 'divided', 'offenses', 'between', 'capital', 'offenses', 'and', 'noncapital', 'offenses', 'again', 'referring', 'solely', 'to', 'crimes', 'and', 'it', 'was', 'very', 'telling', 'that', 'in', '857', 'dualcolumn', 'pages', 'of', 'title', '18', 'neither', 'the', 'government', 'nor', 'relator', 'has', 'been', 'able', 'to', 'identify', 'any', 'provision', 'that', 'uses', 'the', 'word', 'offense', 'to', 'refer', 'to', 'a', 'civil', 'violation', 'is', 'it', 'unusual', 'that', 'a', 'criminal', 'statute', 'of', 'limitations', 'would', 'be', 'much', 'longer', 'than', 'a', 'civil', 'statute', 'of', 'limitations', 'which', 'is', 'the', 'effect', 'of', 'your', 'argument', 'i', 'dont', 'think', 'it', 'is', 'necessarily', 'i', 'mean', 'it', 'depends', 'on', 'what', 'exactly', 'congress', 'is', 'trying', 'to', 'attempt', 'and', 'it', 'reflects', 'some', 'of', 'the', 'differences', 'between', 'how', 'criminal', 'law', 'is', 'prosecuted', 'and', 'civil', 'law', 'is', 'prosecuted', 'because', 'recall', 'that', 'congress', 'did', 'it', 'has', 'its', 'separate', 'provision', 'for', 'recognizing', 'that', 'the', 'false', 'claims', 'act', 'may', 'be', 'hard', 'to', 'investigate', 'at', 'times', 'and', 'it', 'provided', 'a', 'discovery', 'mechanism', 'there', 'that', 'doesnt', 'apply', 'to', 'relators', 'it', 'only', 'applies', 'to', 'the', 'government', 'a', 'threeyear', 'discovery', 'period', 'with', 'a', 'tenyear', 'backstop', 'didnt', 'some', 'states', 'used', 'to', 'have', 'no', 'statute', 'for', 'for', 'murder', 'and', 'yet', 'had', 'a', 'statute', 'of', 'limitations', 'on', 'wrongful', 'death', 'claims', 'i', 'think', 'thats', 'thats', 'the', 'case', 'with', 'respect', 'to', 'state', 'law', 'anyway', 'but', 'i', 'think', 'it', 'all', 'kind', 'of', 'reflects', 'the', 'kind', 'of', 'differences', 'between', 'criminal', 'law', 'and', 'civil', 'law', 'because', 'the', 'minute', 'a', 'complaint', 'is', 'filed', 'i', 'mean', 'most', 'of', 'the', 'investigation', 'especially', 'for', 'relators', 'they', 'dont', 'have', 'any', 'legal', 'status', 'to', 'conduct', 'investigations', 'they', 'dont', 'they', 'cant', 'bring', 'subpoenas', 'so', 'usually', 'its', 'based', 'on', 'their', 'own', 'knowledge', 'they', 'file', 'a', 'complaint', 'they', 'come', 'into', 'court', 'and', 'then', 'they', 'have', 'the', 'federal', 'rules', 'also', 'at', 'that', 'point', 'the', 'government', 'gets', 'a', '60day', 'period', 'to', 'investigate', 'which', 'is', 'on', 'average', '13', 'months', 'according', 'to', 'the', 'chamber', 'of', 'commerce', 'brief', 'it', 'cites', 'a', 'letter', 'from', 'the', 'doj', 'to', 'the', 'senate', 'and', 'in', 'our', 'own', 'experience', 'and', 'in', 'this', 'case', 'it', 'is', 'usually', 'a', 'couple', 'of', 'years', ' ...
#
# Creating vocabulary object
# The idx of 'good' is  278
# The string value of 8 is  a
# LABEL.vocab.stoi is defaultdict(None, {'0.0': 0, '1.0': 1})
#
# Creating a train BucketIterator
#
# Iterating train data (batch_size=2)
#
# =====
#
# ['422', '286']
# tensor([[  2,   2],
#         [ 42,  42],
#         [500, 500],
#         ...,
#         [  1,   9],
#         [  1, 752],
#         [  1,   2]], device='cuda:0')
# tensor([0., 1.], device='cuda:0')
#
# =====
#
# ['495', '15']
# tensor([[  2,   2],
#         [ 42,  21],
#         [500, 115],
#         ...,
#         [  9,   1],
#         [752,   1],
#         [  2,   1]], device='cuda:0')
# tensor([1., 0.], device='cuda:0')
#
# =====
#
# ['24', '301']
# tensor([[  2,   2],
#         [ 42,  21],
#         [500, 115],
#         ...,
#         [  9,   1],
#         [752,   1],
#         [  2,   1]], device='cuda:0')
# tensor([1., 1.], device='cuda:0')
#
# =====
#
# ['363', '222']
# tensor([[  2,   2],
#         [ 42,  42],
#         [500, 500],
#         ...,
#         [  9,   1],
#         [752,   1],
#         [  2,   1]], device='cuda:0')
# tensor([0., 1.], device='cuda:0')
#
# =====
#
# ['596', '6']
# tensor([[  2,   2],
#         [ 42,  42],
#         [500, 500],
#         ...,
#         [  9,   1],
#         [752,   1],
#         [  2,   1]], device='cuda:0')
# tensor([1., 1.], device='cuda:0')
#
# =====
#
# ['144', '194']
# tensor([[  2,   2],
#         [ 42,  21],
#         [500, 115],
#         ...,
#         [  9,   1],
#         [752,   1],
#         [  2,   1]], device='cuda:0')
# tensor([0., 1.], device='cuda:0')
#
# =====
#
# ['480', '433']
# tensor([[  2,   2],
#         [ 42,  21],
#         [500, 115],
#         ...,
#         [  1,   9],
#         [  1, 752],
#         [  1,   2]], device='cuda:0')
# tensor([0., 1.], device='cuda:0')
#
# =====
#
# ['26', '571']
# tensor([[  2,   2],
#         [ 21,  42],
#         [115, 500],
#         ...,
#         [  9,   1],
#         [752,   1],
#         [  2,   1]], device='cuda:0')
# tensor([1., 1.], device='cuda:0')
#
# =====
#
# ['352', '534']
# tensor([[  2,   2],
#         [ 42,  42],
#         [500, 500],
#         ...,
#         [  9,   1],
#         [752,   1],
#         [  2,   1]], device='cuda:0')
# tensor([0., 0.], device='cuda:0')
#
# =====
#
# ['30', '316']
# tensor([[  2,   2],
#         [ 42,  42],
#         [500, 500],
#         ...,
#         [  1,   9],
#         [  1, 752],
#         [  1,   2]], device='cuda:0')
# tensor([1., 1.], device='cuda:0')
#
# =====
#
# ['377', '369']
# tensor([[  2,   2],
#         [ 42,  42],
#         [500, 500],
#         ...,
#         [  9,   1],
#         [752,   1],
#         [  2,   1]], device='cuda:0')
# tensor([1., 1.], device='cuda:0')
#
# =====
#
# ['104', '496']
# tensor([[  2,   2],
#         [ 21,  42],
#         [115, 500],
#         ...,
#         [  1,   9],
#         [  1, 752],
#         [  1,   2]], device='cuda:0')
# tensor([1., 0.], device='cuda:0')
#
# =====
#
# ['462', '352']
# tensor([[  2,   2],
#         [ 42,  42],
#         [500, 500],
#         ...,
#         [  1,   9],
#         [  1, 752],
#         [  1,   2]], device='cuda:0')
# tensor([0., 0.], device='cuda:0')
#
# =====
#
# ['352', '114']
# tensor([[  2,   2],
#         [ 42,  42],
#         [500, 500],
#         ...,
#         [  9,   1],
#         [752,   1],
#         [  2,   1]], device='cuda:0')
# tensor([0., 0.], device='cuda:0')
#
# =====
#
# ['305', '361']
# tensor([[  2,   2],
#         [ 21,  42],
#         [115, 500],
#         ...,
#         [  1, 172],
#         [  1,  13],
#         [  1,   2]], device='cuda:0')
# tensor([0., 0.], device='cuda:0')
#
# =====
#
# ['103', '245']
# tensor([[  2,   2],
#         [ 21, 108],
#         [115, 104],
#         ...,
#         [  9,   1],
#         [752,   1],
#         [  2,   1]], device='cuda:0')
# tensor([0., 0.], device='cuda:0')
#
# =====
#
# ['538', '148']
# tensor([[  2,   2],
#         [ 42,  42],
#         [500, 500],
#         ...,
#         [  1,   9],
#         [  1, 752],
#         [  1,   2]], device='cuda:0')
# tensor([0., 0.], device='cuda:0')
#
# =====
#
# ['547', '248']
# tensor([[  2,   2],
#         [ 42,  21],
#         [500, 115],
#         ...,
#         [  1,   9],
#         [  1, 752],
#         [  1,   2]], device='cuda:0')
# tensor([0., 0.], device='cuda:0')
#
# =====
#
# ['297', '434']
# tensor([[  2,   2],
#         [ 42,  42],
#         [500, 500],
#         ...,
#         [  9,   1],
#         [752,   1],
#         [  2,   1]], device='cuda:0')
# tensor([0., 1.], device='cuda:0')
#
# =====
#
# ['400', '135']
# tensor([[  2,   2],
#         [ 21,  21],
#         [115, 115],
#         ...,
#         [  9,   1],
#         [752,   1],
#         [  2,   1]], device='cuda:0')
# tensor([0., 1.], device='cuda:0')
#
# =====
#
# ['124', '438']
# tensor([[  2,   2],
#         [ 21,  42],
#         [115, 500],
#         ...,
#         [  9,   1],
#         [752,   1],
#         [  2,   1]], device='cuda:0')
# tensor([0., 1.], device='cuda:0')
#
# =====
#
# ['299', '371']
# tensor([[  2,   2],
#         [ 42,  42],
#         [500, 500],
#         ...,
#         [  9,   1],
#         [752,   1],
#         [  2,   1]], device='cuda:0')
# tensor([1., 0.], device='cuda:0')
#
# =====
#
# ['590', '450']
# tensor([[  2,   2],
#         [ 42,  42],
#         [500, 500],
#         ...,
#         [  9,   1],
#         [752,   1],
#         [  2,   1]], device='cuda:0')
# tensor([1., 1.], device='cuda:0')
#
# =====
#
# ['207', '89']
# tensor([[  2,   2],
#         [ 42,  42],
#         [500, 500],
#         ...,
#         [  1,   9],
#         [  1, 752],
#         [  1,   2]], device='cuda:0')
# tensor([1., 0.], device='cuda:0')
#
# =====
#
# ['185', '556']
# tensor([[  2,   2],
#         [ 42,  42],
#         [500, 500],
#         ...,
#         [  1,   9],
#         [  1, 752],
#         [  1,   2]], device='cuda:0')
# tensor([1., 1.], device='cuda:0')
#
# =====
#
# ['310', '132']
# tensor([[  2,   2],
#         [ 21,  21],
#         [115, 115],
#         ...,
#         [  1,   9],
#         [  1, 752],
#         [  1,   2]], device='cuda:0')
# tensor([1., 1.], device='cuda:0')
#
# =====
#
# ['396', '513']
# tensor([[  2,   2],
#         [ 42,  42],
#         [500, 500],
#         ...,
#         [  1,   9],
#         [  1, 752],
#         [  1,   2]], device='cuda:0')
# tensor([0., 1.], device='cuda:0')
#
# =====
#
# ['188', '146']
# tensor([[  2,   2],
#         [ 42,  42],
#         [500, 500],
#         ...,
#         [  1,   9],
#         [  1, 752],
#         [  1,   2]], device='cuda:0')
# tensor([1., 1.], device='cuda:0')
#
# =====
#
# ['411', '365']
# tensor([[  2,   2],
#         [ 42,  42],
#         [500, 500],
#         ...,
#         [  9,   1],
#         [752,   1],
#         [  2,   1]], device='cuda:0')
# tensor([1., 0.], device='cuda:0')
#
# =====
#
# ['297', '271']
# tensor([[  2,   2],
#         [ 42,  21],
#         [500, 115],
#         ...,
#         [  1,   9],
#         [  1, 752],
#         [  1,   2]], device='cuda:0')
# tensor([0., 0.], device='cuda:0')
#
# =====
#
# ['368', '402']
# tensor([[  2,   2],
#         [ 42,  42],
#         [500, 500],
#         ...,
#         [  1,   9],
#         [  1, 752],
#         [  1,   2]], device='cuda:0')
# tensor([0., 0.], device='cuda:0')
#
# =====
#
# ['420', '158']
# tensor([[  2,   2],
#         [ 42,  42],
#         [500, 500],
#         ...,
#         [  9,   1],
#         [752,   1],
#         [  2,   1]], device='cuda:0')
# tensor([1., 0.], device='cuda:0')
#
# =====
#
# ['449', '573']
# tensor([[  2,   2],
#         [ 42,  42],
#         [500, 500],
#         ...,
#         [  9,   1],
#         [752,   1],
#         [  2,   1]], device='cuda:0')
# tensor([1., 1.], device='cuda:0')
#
# =====
#
# ['113', '517']
# tensor([[  2,   2],
#         [ 21,  42],
#         [115, 500],
#         ...,
#         [  1,   9],
#         [  1, 752],
#         [  1,   2]], device='cuda:0')
# tensor([1., 1.], device='cuda:0')
#
# =====
#
# ['533', '309']
# tensor([[  2,   2],
#         [ 42,  42],
#         [500, 500],
#         ...,
#         [  9,   1],
#         [752,   1],
#         [  2,   1]], device='cuda:0')
# tensor([1., 0.], device='cuda:0')
#
# =====
#
# ['114', '56']
# tensor([[  2,   2],
#         [ 42,  42],
#         [500, 500],
#         ...,
#         [  9,   1],
#         [752,   1],
#         [  2,   1]], device='cuda:0')
# tensor([0., 1.], device='cuda:0')
#
# =====
#
# ['168', '173']
# tensor([[  2,   2],
#         [ 42,  42],
#         [500, 500],
#         ...,
#         [  9,   1],
#         [752,   1],
#         [  2,   1]], device='cuda:0')
# tensor([0., 1.], device='cuda:0')
#
# =====
#
# ['262', '249']
# tensor([[  2,   2],
#         [ 21,  21],
#         [115, 115],
#         ...,
#         [  1,   9],
#         [  1, 752],
#         [  1,   2]], device='cuda:0')
# tensor([1., 0.], device='cuda:0')
#
# =====
#
# ['167', '79']
# tensor([[  2,   2],
#         [ 21,  21],
#         [115, 115],
#         ...,
#         [  9,   1],
#         [752,   1],
#         [  2,   1]], device='cuda:0')
# tensor([0., 0.], device='cuda:0')
#
# =====
#
# ['17', '364']
# tensor([[  2,   2],
#         [ 42,  42],
#         [500, 500],
#         ...,
#         [  1,   9],
#         [  1, 752],
#         [  1,   2]], device='cuda:0')
# tensor([1., 1.], device='cuda:0')
#
# =====
#
# ['165', '425']
# tensor([[  2,   2],
#         [ 42,  21],
#         [500, 115],
#         ...,
#         [  9,   1],
#         [752,   1],
#         [  2,   1]], device='cuda:0')
# tensor([1., 0.], device='cuda:0')
#
# =====
#
# ['483', '331']
# tensor([[  2,   2],
#         [ 42,  21],
#         [500, 115],
#         ...,
#         [  9,   1],
#         [752,   1],
#         [  2,   1]], device='cuda:0')
# tensor([1., 1.], device='cuda:0')
#
# =====
#
# ['29', '319']
# tensor([[  2,   2],
#         [ 21,  42],
#         [115, 500],
#         ...,
#         [  1,   9],
#         [  1, 752],
#         [  1,   2]], device='cuda:0')
# tensor([1., 1.], device='cuda:0')
#
# =====
#
# ['158', '477']
# tensor([[  2,   2],
#         [ 42,  42],
#         [500, 500],
#         ...,
#         [  1,   9],
#         [  1, 752],
#         [  1,   2]], device='cuda:0')
# tensor([0., 0.], device='cuda:0')
#
# =====
#
# ['576', '39']
# tensor([[  2,   2],
#         [ 42,  21],
#         [500, 115],
#         ...,
#         [  1,   9],
#         [  1, 752],
#         [  1,   2]], device='cuda:0')
# tensor([1., 1.], device='cuda:0')
#
# =====
#
# ['546', '88']
# tensor([[  2,   2],
#         [ 42,  42],
#         [500, 500],
#         ...,
#         [  9,   1],
#         [752,   1],
#         [  2,   1]], device='cuda:0')
# tensor([1., 1.], device='cuda:0')
#
# =====
#
# ['578', '570']
# tensor([[  2,   2],
#         [ 42,  42],
#         [500, 500],
#         ...,
#         [  1,   9],
#         [  1, 752],
#         [  1,   2]], device='cuda:0')
# tensor([0., 1.], device='cuda:0')
#
# =====
#
# ['268', '229']
# tensor([[  2,   2],
#         [ 42,  21],
#         [500, 115],
#         ...,
#         [  9,   1],
#         [752,   1],
#         [  2,   1]], device='cuda:0')
# tensor([1., 1.], device='cuda:0')
#
# =====
#
# ['429', '131']
# tensor([[  2,   2],
#         [ 42,  42],
#         [500, 500],
#         ...,
#         [  9,   1],
#         [752,   1],
#         [  2,   1]], device='cuda:0')
# tensor([1., 1.], device='cuda:0')
#
# =====
#
# ['195', '250']
# tensor([[  2,   2],
#         [ 21,  42],
#         [115, 500],
#         ...,
#         [  1,   9],
#         [  1, 752],
#         [  1,   2]], device='cuda:0')
# tensor([1., 1.], device='cuda:0')
#
# =====
#
# ['465', '518']
# tensor([[  2,   2],
#         [ 42,  42],
#         [500, 500],
#         ...,
#         [  9,   1],
#         [752,   1],
#         [  2,   1]], device='cuda:0')
# tensor([0., 0.], device='cuda:0')
#
# =====
#
# ['557', '400']
# tensor([[  2,   2],
#         [ 42,  21],
#         [500, 115],
#         ...,
#         [  1,   9],
#         [  1, 752],
#         [  1,   2]], device='cuda:0')
# tensor([1., 0.], device='cuda:0')
#
# =====
#
# ['383', '67']
# tensor([[  2,   2],
#         [ 42,  21],
#         [500, 115],
#         ...,
#         [  1,   9],
#         [  1, 752],
#         [  1,   2]], device='cuda:0')
# tensor([0., 1.], device='cuda:0')
#
# =====
#
# ['335', '172']
# tensor([[  2,   2],
#         [ 21,  21],
#         [115, 115],
#         ...,
#         [  1,   9],
#         [  1, 752],
#         [  1,   2]], device='cuda:0')
# tensor([1., 1.], device='cuda:0')
#
# =====
#
# ['527', '70']
# tensor([[  2,   2],
#         [ 42,  21],
#         [500, 115],
#         ...,
#         [  9,   1],
#         [752,   1],
#         [  2,   1]], device='cuda:0')
# tensor([1., 0.], device='cuda:0')
#
# =====
#
# ['37', '196']
# tensor([[  2,   2],
#         [ 21,  42],
#         [115, 500],
#         ...,
#         [ 37,   1],
#         [ 83,   1],
#         [  2,   1]], device='cuda:0')
# tensor([0., 0.], device='cuda:0')
#
# =====
#
# ['350', '90']
# tensor([[  2,   2],
#         [ 42,  42],
#         [500, 500],
#         ...,
#         [  1,   9],
#         [  1, 752],
#         [  1,   2]], device='cuda:0')
# tensor([0., 0.], device='cuda:0')
#
# =====
#
# ['505', '469']
# tensor([[  2,   2],
#         [ 42,  42],
#         [500, 500],
#         ...,
#         [  9,   1],
#         [752,   1],
#         [  2,   1]], device='cuda:0')
# tensor([0., 1.], device='cuda:0')
#
# =====
#
# ['349', '380']
# tensor([[  2,   2],
#         [ 42,  21],
#         [500, 115],
#         ...,
#         [  9,   1],
#         [752,   1],
#         [  2,   1]], device='cuda:0')
# tensor([0., 0.], device='cuda:0')
#
# =====
#
# ['81', '445']
# tensor([[  2,   2],
#         [ 42,  42],
#         [500, 500],
#         ...,
#         [  9,   1],
#         [752,   1],
#         [  2,   1]], device='cuda:0')
# tensor([0., 1.], device='cuda:0')
#
# =====
#
# ['287', '211']
# tensor([[  2,   2],
#         [ 21,  42],
#         [115, 500],
#         ...,
#         [  1,   9],
#         [  1, 752],
#         [  1,   2]], device='cuda:0')
# tensor([1., 0.], device='cuda:0')
#
# =====
#
# ['322', '380']
# tensor([[  2,   2],
#         [ 42,  21],
#         [500, 115],
#         ...,
#         [  1,   9],
#         [  1, 752],
#         [  1,   2]], device='cuda:0')
# tensor([0., 0.], device='cuda:0')
#
# =====
#
# ['93', '182']
# tensor([[  2,   2],
#         [ 21,  42],
#         [115, 500],
#         ...,
#         [  1,   9],
#         [  1, 752],
#         [  1,   2]], device='cuda:0')
# tensor([0., 1.], device='cuda:0')
#
# =====
#
# ['368', '190']
# tensor([[  2,   2],
#         [ 42,  42],
#         [500, 500],
#         ...,
#         [  1,   9],
#         [  1, 752],
#         [  1,   2]], device='cuda:0')
# tensor([0., 1.], device='cuda:0')
#
# =====
#
# ['468', '38']
# tensor([[  2,   2],
#         [ 42,  21],
#         [500, 115],
#         ...,
#         [  1,  38],
#         [  1, 752],
#         [  1,   2]], device='cuda:0')
# tensor([0., 0.], device='cuda:0')
#
# =====
#
# ['548', '259']
# tensor([[  2,   2],
#         [ 42,  21],
#         [500, 115],
#         ...,
#         [  1,   9],
#         [  1, 752],
#         [  1,   2]], device='cuda:0')
# tensor([1., 1.], device='cuda:0')
#
# =====
#
# ['329', '153']
# tensor([[  2,   2],
#         [ 42,  42],
#         [500, 500],
#         ...,
#         [  9,   1],
#         [752,   1],
#         [  2,   1]], device='cuda:0')
# tensor([0., 1.], device='cuda:0')
#
# =====
#
# ['81', '581']
# tensor([[  2,   2],
#         [ 42,  42],
#         [500, 500],
#         ...,
#         [  9,   1],
#         [752,   1],
#         [  2,   1]], device='cuda:0')
# tensor([0., 0.], device='cuda:0')
#
# =====
#
# ['81', '118']
# tensor([[  2,   2],
#         [ 42,  21],
#         [500, 115],
#         ...,
#         [  9,   1],
#         [752,   1],
#         [  2,   1]], device='cuda:0')
# tensor([0., 0.], device='cuda:0')
#
# =====
#
# ['584', '380']
# tensor([[  2,   2],
#         [ 42,  21],
#         [500, 115],
#         ...,
#         [  1,   9],
#         [  1, 752],
#         [  1,   2]], device='cuda:0')
# tensor([1., 0.], device='cuda:0')
#
# =====
#
# ['174', '561']
# tensor([[  2,   2],
#         [ 21,  21],
#         [115, 115],
#         ...,
#         [  1,   9],
#         [  1, 752],
#         [  1,   2]], device='cuda:0')
# tensor([1., 0.], device='cuda:0')
#
# =====
#
# ['405', '539']
# tensor([[  2,   2],
#         [ 42,  42],
#         [500, 500],
#         ...,
#         [  1,   9],
#         [  1, 752],
#         [  1,   2]], device='cuda:0')
# tensor([1., 1.], device='cuda:0')
#
# =====
#
# ['416', '114']
# tensor([[  2,   2],
#         [ 42,  42],
#         [500, 500],
#         ...,
#         [  1,   9],
#         [  1, 752],
#         [  1,   2]], device='cuda:0')
# tensor([0., 0.], device='cuda:0')
#
# =====
#
# ['595', '320']
# tensor([[  2,   2],
#         [ 42,  21],
#         [500, 115],
#         ...,
#         [  9,   1],
#         [752,   1],
#         [  2,   1]], device='cuda:0')
# tensor([0., 1.], device='cuda:0')
#
# =====
#
# ['36', '84']
# tensor([[  2,   2],
#         [ 21,  21],
#         [115, 115],
#         ...,
#         [172,   1],
#         [ 13,   1],
#         [  2,   1]], device='cuda:0')
# tensor([0., 1.], device='cuda:0')
#
# =====
#
# ['25', '336']
# tensor([[  2,   2],
#         [ 21,  42],
#         [115, 500],
#         ...,
#         [  9,   1],
#         [752,   1],
#         [  2,   1]], device='cuda:0')
# tensor([1., 0.], device='cuda:0')
#
# =====
#
# ['218', '86']
# tensor([[  2,   2],
#         [ 42,  42],
#         [500, 500],
#         ...,
#         [  1,   9],
#         [  1, 752],
#         [  1,   2]], device='cuda:0')
# tensor([0., 0.], device='cuda:0')
#
# =====
#
# ['266', '290']
# tensor([[  2,   2],
#         [ 21,  42],
#         [115, 500],
#         ...,
#         [  9,   1],
#         [752,   1],
#         [  2,   1]], device='cuda:0')
# tensor([1., 1.], device='cuda:0')
#
# =====
#
# ['479', '15']
# tensor([[  2,   2],
#         [ 42,  21],
#         [500, 115],
#         ...,
#         [  9,   1],
#         [752,   1],
#         [  2,   1]], device='cuda:0')
# tensor([0., 0.], device='cuda:0')
#
# =====
#
# ['218', '278']
# tensor([[  2,   2],
#         [ 42,  42],
#         [500, 500],
#         ...,
#         [  1,   9],
#         [  1, 752],
#         [  1,   2]], device='cuda:0')
# tensor([0., 0.], device='cuda:0')
#
# =====
#
# ['452', '536']
# tensor([[  2,   2],
#         [ 42,  42],
#         [500, 500],
#         ...,
#         [  9,   1],
#         [752,   1],
#         [  2,   1]], device='cuda:0')
# tensor([1., 0.], device='cuda:0')
#
# =====
#
# ['346', '357']
# tensor([[  2,   2],
#         [ 42,  42],
#         [500, 500],
#         ...,
#         [  1,   9],
#         [  1, 752],
#         [  1,   2]], device='cuda:0')
# tensor([0., 1.], device='cuda:0')
#
# =====
#
# ['103', '176']
# tensor([[  2,   2],
#         [ 21,  42],
#         [115, 500],
#         ...,
#         [  1,   9],
#         [  1, 752],
#         [  1,   2]], device='cuda:0')
# tensor([0., 0.], device='cuda:0')
#
# =====
#
# ['291', '78']
# tensor([[  2,   2],
#         [ 42,  21],
#         [500, 115],
#         ...,
#         [  1,   9],
#         [  1, 752],
#         [  1,   2]], device='cuda:0')
# tensor([1., 1.], device='cuda:0')
#
# =====
#
# ['440', '72']
# tensor([[  2,   2],
#         [ 42,  21],
#         [500, 115],
#         ...,
#         [  9,   1],
#         [752,   1],
#         [  2,   1]], device='cuda:0')
# tensor([1., 1.], device='cuda:0')
#
# =====
#
# ['398', '296']
# tensor([[  2,   2],
#         [ 42,  21],
#         [500, 115],
#         ...,
#         [  9,   1],
#         [752,   1],
#         [  2,   1]], device='cuda:0')
# tensor([1., 0.], device='cuda:0')
#
# =====
#
# ['318', '490']
# tensor([[  2,   2],
#         [ 21,  42],
#         [115, 500],
#         ...,
#         [  1,   9],
#         [  1, 752],
#         [  1,   2]], device='cuda:0')
# tensor([1., 1.], device='cuda:0')
#
# =====
#
# ['298', '82']
# tensor([[  2,   2],
#         [ 42,  42],
#         [500, 500],
#         ...,
#         [  1,   9],
#         [  1, 752],
#         [  1,   2]], device='cuda:0')
# tensor([0., 0.], device='cuda:0')
#
# =====
#
# ['304', '277']
# tensor([[  2,   2],
#         [ 42,  42],
#         [500, 500],
#         ...,
#         [  1,   9],
#         [  1, 752],
#         [  1,   2]], device='cuda:0')
# tensor([0., 0.], device='cuda:0')
#
# =====
#
# ['395', '5']
# tensor([[  2,   2],
#         [ 42,  21],
#         [500, 115],
#         ...,
#         [  9,   1],
#         [752,   1],
#         [  2,   1]], device='cuda:0')
# tensor([1., 1.], device='cuda:0')
#
# =====
#
# ['37', '531']
# tensor([[  2,   2],
#         [ 21,  42],
#         [115, 500],
#         ...,
#         [  1,   9],
#         [  1, 752],
#         [  1,   2]], device='cuda:0')
# tensor([0., 1.], device='cuda:0')
#
# =====
#
# ['549', '11']
# tensor([[  2,   2],
#         [ 42,  21],
#         [500, 115],
#         ...,
#         [  9,   1],
#         [752,   1],
#         [  2,   1]], device='cuda:0')
# tensor([1., 1.], device='cuda:0')
#
# =====
#
# ['199', '101']
# tensor([[  2,   2],
#         [ 42,  21],
#         [500, 115],
#         ...,
#         [  9,   1],
#         [752,   1],
#         [  2,   1]], device='cuda:0')
# tensor([1., 1.], device='cuda:0')
#
# =====
#
# ['579', '300']
# tensor([[  2,   2],
#         [ 42,  42],
#         [500, 500],
#         ...,
#         [  9,   1],
#         [752,   1],
#         [  2,   1]], device='cuda:0')
# tensor([0., 0.], device='cuda:0')
#
# =====
#
# ['0', '362']
# tensor([[  2,   2],
#         [ 21,  42],
#         [115, 500],
#         ...,
#         [ 37,   1],
#         [ 83,   1],
#         [  2,   1]], device='cuda:0')
# tensor([0., 0.], device='cuda:0')
#
# =====
#
# ['425', '574']
# tensor([[  2,   2],
#         [ 21,  42],
#         [115, 500],
#         ...,
#         [  1,   9],
#         [  1, 752],
#         [  1,   2]], device='cuda:0')
# tensor([0., 1.], device='cuda:0')
#
# =====
#
# ['23', '333']
# tensor([[  2,   2],
#         [ 21,  42],
#         [115, 500],
#         ...,
#         [  9,   1],
#         [752,   1],
#         [  2,   1]], device='cuda:0')
# tensor([0., 1.], device='cuda:0')
#
# =====
#
# ['157', '559']
# tensor([[  2,   2],
#         [ 42,  42],
#         [500, 500],
#         ...,
#         [  9,   1],
#         [752,   1],
#         [  2,   1]], device='cuda:0')
# tensor([0., 0.], device='cuda:0')
#
# =====
#
# ['303', '312']
# tensor([[  2,   2],
#         [ 42,  42],
#         [500, 500],
#         ...,
#         [  1,   9],
#         [  1, 752],
#         [  1,   2]], device='cuda:0')
# tensor([1., 1.], device='cuda:0')
#
# =====
#
# ['363', '371']
# tensor([[  2,   2],
#         [ 42,  42],
#         [500, 500],
#         ...,
#         [  9,   1],
#         [752,   1],
#         [  2,   1]], device='cuda:0')
# tensor([0., 0.], device='cuda:0')
#
# =====
#
# ['247', '563']
# tensor([[  2,   2],
#         [ 21,  42],
#         [115, 500],
#         ...,
#         [  1,   9],
#         [  1, 752],
#         [  1,   2]], device='cuda:0')
# tensor([0., 1.], device='cuda:0')
#
# =====
#
# ['253', '261']
# tensor([[  2,   2],
#         [ 42,  21],
#         [500, 115],
#         ...,
#         [  1,   9],
#         [  1, 752],
#         [  1,   2]], device='cuda:0')
# tensor([0., 0.], device='cuda:0')
#
# =====
#
# ['525', '480']
# tensor([[  2,   2],
#         [ 42,  42],
#         [500, 500],
#         ...,
#         [  1,   9],
#         [  1, 752],
#         [  1,   2]], device='cuda:0')
# tensor([0., 0.], device='cuda:0')
#
# =====
#
# ['141', '547']
# tensor([[  2,   2],
#         [ 21,  42],
#         [115, 500],
#         ...,
#         [  9,   1],
#         [752,   1],
#         [  2,   1]], device='cuda:0')
# tensor([1., 0.], device='cuda:0')
#
# =====
#
# ['361', '90']
# tensor([[  2,   2],
#         [ 42,  42],
#         [500, 500],
#         ...,
#         [172,   1],
#         [ 13,   1],
#         [  2,   1]], device='cuda:0')
# tensor([0., 0.], device='cuda:0')
#
# =====
#
# ['578', '70']
# tensor([[  2,   2],
#         [ 42,  21],
#         [500, 115],
#         ...,
#         [  9,   1],
#         [752,   1],
#         [  2,   1]], device='cuda:0')
# tensor([0., 0.], device='cuda:0')
#
# =====
#
# ['176', '348']
# tensor([[  2,   2],
#         [ 42,  42],
#         [500, 500],
#         ...,
#         [  9,   1],
#         [752,   1],
#         [  2,   1]], device='cuda:0')
# tensor([0., 1.], device='cuda:0')
#
# =====
#
# ['363', '329']
# tensor([[  2,   2],
#         [ 42,  42],
#         [500, 500],
#         ...,
#         [  9,   1],
#         [752,   1],
#         [  2,   1]], device='cuda:0')
# tensor([0., 0.], device='cuda:0')
#
# =====
#
# ['181', '507']
# tensor([[  2,   2],
#         [ 21,  42],
#         [115, 500],
#         ...,
#         [  1,   9],
#         [  1, 752],
#         [  1,   2]], device='cuda:0')
# tensor([0., 1.], device='cuda:0')
#
# =====
#
# ['19', '487']
# tensor([[  2,   2],
#         [ 42,  42],
#         [500, 500],
#         ...,
#         [  1,   9],
#         [  1, 752],
#         [  1,   2]], device='cuda:0')
# tensor([0., 1.], device='cuda:0')
#
# =====
#
# ['55', '350']
# tensor([[  2,   2],
#         [ 21,  42],
#         [115, 500],
#         ...,
#         [  1,   9],
#         [  1, 752],
#         [  1,   2]], device='cuda:0')
# tensor([1., 0.], device='cuda:0')
#
# =====
#
# ['144', '532']
# tensor([[  2,   2],
#         [ 42,  42],
#         [500, 500],
#         ...,
#         [  1,   9],
#         [  1, 752],
#         [  1,   2]], device='cuda:0')
# tensor([0., 0.], device='cuda:0')
#
# =====
#
# ['228', '124']
# tensor([[  2,   2],
#         [ 21,  21],
#         [115, 115],
#         ...,
#         [  9,   1],
#         [752,   1],
#         [  2,   1]], device='cuda:0')
# tensor([1., 0.], device='cuda:0')
#
# =====
#
# ['220', '456']
# tensor([[  2,   2],
#         [ 21,  42],
#         [115, 500],
#         ...,
#         [  1,   9],
#         [  1, 752],
#         [  1,   2]], device='cuda:0')
# tensor([1., 1.], device='cuda:0')
#
# =====
#
# ['328', '81']
# tensor([[  2,   2],
#         [ 42,  42],
#         [500, 500],
#         ...,
#         [  1,   9],
#         [  1, 752],
#         [  1,   2]], device='cuda:0')
# tensor([1., 0.], device='cuda:0')
#
# =====
#
# ['36', '334']
# tensor([[  2,   2],
#         [ 21,  42],
#         [115, 500],
#         ...,
#         [  1,   0],
#         [  1, 419],
#         [  1,   2]], device='cuda:0')
# tensor([0., 1.], device='cuda:0')
#
# =====
#
# ['163', '7']
# tensor([[  2,   2],
#         [ 79,  21],
#         [186, 115],
#         ...,
#         [  9,   1],
#         [752,   1],
#         [  2,   1]], device='cuda:0')
# tensor([1., 1.], device='cuda:0')
#
# =====
#
# ['388', '322']
# tensor([[  2,   2],
#         [ 42,  42],
#         [500, 500],
#         ...,
#         [  1,   9],
#         [  1, 752],
#         [  1,   2]], device='cuda:0')
# tensor([0., 0.], device='cuda:0')
#
# =====
#
# ['344', '400']
# tensor([[  2,   2],
#         [ 42,  21],
#         [500, 115],
#         ...,
#         [  1,   9],
#         [  1, 752],
#         [  1,   2]], device='cuda:0')
# tensor([1., 0.], device='cuda:0')
#
# =====
#
# ['68', '46']
# tensor([[  2,   2],
#         [108,  42],
#         [544, 500],
#         ...,
#         [  9,   1],
#         [752,   1],
#         [  2,   1]], device='cuda:0')
# tensor([1., 1.], device='cuda:0')
#
# =====
#
# ['272', '365']
# tensor([[  2,   2],
#         [ 42,  42],
#         [500, 500],
#         ...,
#         [  9,   1],
#         [752,   1],
#         [  2,   1]], device='cuda:0')
# tensor([1., 0.], device='cuda:0')
#
# =====
#
# ['572', '23']
# tensor([[  2,   2],
#         [ 42,  21],
#         [500, 115],
#         ...,
#         [  1,   9],
#         [  1, 752],
#         [  1,   2]], device='cuda:0')
# tensor([1., 0.], device='cuda:0')
#
# =====
#
# ['553', '69']
# tensor([[  2,   2],
#         [ 42,  42],
#         [500, 500],
#         ...,
#         [  9,   1],
#         [752,   1],
#         [  2,   1]], device='cuda:0')
# tensor([0., 1.], device='cuda:0')
#
# =====
#
# ['154', '581']
# tensor([[  2,   2],
#         [ 42,  42],
#         [500, 500],
#         ...,
#         [  9,   1],
#         [752,   1],
#         [  2,   1]], device='cuda:0')
# tensor([1., 0.], device='cuda:0')
#
# =====
#
# ['109', '592']
# tensor([[  2,   2],
#         [ 42,  42],
#         [500, 500],
#         ...,
#         [  9,   1],
#         [752,   1],
#         [  2,   1]], device='cuda:0')
# tensor([0., 1.], device='cuda:0')
#
# =====
#
# ['393', '368']
# tensor([[  2,   2],
#         [ 42,  42],
#         [500, 500],
#         ...,
#         [  9,   1],
#         [752,   1],
#         [  2,   1]], device='cuda:0')
# tensor([1., 0.], device='cuda:0')
#
# =====
#
# ['15', '238']
# tensor([[  2,   2],
#         [ 21,  42],
#         [115, 500],
#         ...,
#         [  1,   9],
#         [  1, 752],
#         [  1,   2]], device='cuda:0')
# tensor([0., 1.], device='cuda:0')
#
# =====
#
# ['231', '225']
# tensor([[  2,   2],
#         [ 42,  42],
#         [500, 500],
#         ...,
#         [  9,   1],
#         [752,   1],
#         [  2,   1]], device='cuda:0')
# tensor([1., 1.], device='cuda:0')
#
# =====
#
# ['381', '257']
# tensor([[  2,   2],
#         [ 42,  21],
#         [500, 115],
#         ...,
#         [  1,   9],
#         [  1, 752],
#         [  1,   2]], device='cuda:0')
# tensor([1., 1.], device='cuda:0')
#
# =====
#
# ['478', '353']
# tensor([[  2,   2],
#         [ 42,  42],
#         [500, 500],
#         ...,
#         [  1,   9],
#         [  1, 752],
#         [  1,   2]], device='cuda:0')
# tensor([1., 1.], device='cuda:0')
#
# =====
#
# ['524', '547']
# tensor([[  2,   2],
#         [ 42,  42],
#         [500, 500],
#         ...,
#         [  1,   9],
#         [  1, 752],
#         [  1,   2]], device='cuda:0')
# tensor([1., 0.], device='cuda:0')
#
# =====
#
# ['589', '54']
# tensor([[  2,   2],
#         [ 42,  21],
#         [500, 115],
#         ...,
#         [  9,   1],
#         [752,   1],
#         [  2,   1]], device='cuda:0')
# tensor([0., 1.], device='cuda:0')
#
# =====
#
# ['193', '518']
# tensor([[  2,   2],
#         [ 21,  42],
#         [115, 500],
#         ...,
#         [  9,   1],
#         [752,   1],
#         [  2,   1]], device='cuda:0')
# tensor([0., 0.], device='cuda:0')
#
# =====
#
# ['509', '437']
# tensor([[  2,   2],
#         [ 42,  42],
#         [500, 500],
#         ...,
#         [  9,   1],
#         [752,   1],
#         [  2,   1]], device='cuda:0')
# tensor([1., 0.], device='cuda:0')
#
# =====
#
# ['31', '396']
# tensor([[  2,   2],
#         [ 42,  42],
#         [500, 500],
#         ...,
#         [  9,   1],
#         [752,   1],
#         [  2,   1]], device='cuda:0')
# tensor([1., 0.], device='cuda:0')
#
# =====
#
# ['8', '196']
# tensor([[  2,   2],
#         [ 42,  42],
#         [500, 500],
#         ...,
#         [  9,   1],
#         [752,   1],
#         [  2,   1]], device='cuda:0')
# tensor([1., 0.], device='cuda:0')
#
# =====
#
# ['118', '340']
# tensor([[  2,   2],
#         [ 21,  42],
#         [115, 500],
#         ...,
#         [  1,   9],
#         [  1, 752],
#         [  1,   2]], device='cuda:0')
# tensor([0., 1.], device='cuda:0')
#
# =====
#
# ['48', '581']
# tensor([[  2,   2],
#         [ 21,  42],
#         [115, 500],
#         ...,
#         [  1,   9],
#         [  1, 752],
#         [  1,   2]], device='cuda:0')
# tensor([1., 0.], device='cuda:0')
#
# =====
#
# ['552', '416']
# tensor([[  2,   2],
#         [ 42,  42],
#         [500, 500],
#         ...,
#         [  1,   9],
#         [  1, 752],
#         [  1,   2]], device='cuda:0')
# tensor([1., 0.], device='cuda:0')
#
# =====
#
# ['63', '227']
# tensor([[  2,   2],
#         [ 21,  42],
#         [115, 500],
#         ...,
#         [  1,   9],
#         [  1, 752],
#         [  1,   2]], device='cuda:0')
# tensor([1., 0.], device='cuda:0')
#
# =====
#
# ['516', '436']
# tensor([[  2,   2],
#         [ 42,  42],
#         [500, 500],
#         ...,
#         [  9,   1],
#         [752,   1],
#         [  2,   1]], device='cuda:0')
# tensor([1., 1.], device='cuda:0')
#
# =====
#
# ['167', '81']
# tensor([[  2,   2],
#         [ 21,  42],
#         [115, 500],
#         ...,
#         [  9,   1],
#         [752,   1],
#         [  2,   1]], device='cuda:0')
# tensor([0., 0.], device='cuda:0')
#
# =====
#
# ['473', '42']
# tensor([[  2,   2],
#         [ 42,  21],
#         [500, 115],
#         ...,
#         [  9,   1],
#         [752,   1],
#         [  2,   1]], device='cuda:0')
# tensor([1., 1.], device='cuda:0')
#
# =====
#
# ['536', '443']
# tensor([[  2,   2],
#         [ 42,  42],
#         [500, 500],
#         ...,
#         [  9,   1],
#         [752,   1],
#         [  2,   1]], device='cuda:0')
# tensor([0., 1.], device='cuda:0')
#
# =====
#
# ['416', '463']
# tensor([[  2,   2],
#         [ 42,  42],
#         [500, 500],
#         ...,
#         [  1,   9],
#         [  1, 752],
#         [  1,   2]], device='cuda:0')
# tensor([0., 1.], device='cuda:0')
#
# =====
#
# ['408', '265']
# tensor([[  2,   2],
#         [ 42,  42],
#         [500, 500],
#         ...,
#         [  9,   1],
#         [752,   1],
#         [  2,   1]], device='cuda:0')
# tensor([1., 1.], device='cuda:0')
#
# =====
#
# ['253', '271']
# tensor([[  2,   2],
#         [ 42,  21],
#         [500, 115],
#         ...,
#         [  1,   9],
#         [  1, 752],
#         [  1,   2]], device='cuda:0')
# tensor([0., 0.], device='cuda:0')
#
# =====
#
# ['119', '355']
# tensor([[  2,   2],
#         [ 42,  42],
#         [500, 500],
#         ...,
#         [  1,   9],
#         [  1, 752],
#         [  1,   2]], device='cuda:0')
# tensor([1., 0.], device='cuda:0')
#
# =====
#
# ['249', '525']
# tensor([[  2,   2],
#         [ 21,  42],
#         [115, 500],
#         ...,
#         [  9,   1],
#         [752,   1],
#         [  2,   1]], device='cuda:0')
# tensor([0., 0.], device='cuda:0')
#
# =====
#
# ['124', '126']
# tensor([[  2,   2],
#         [ 21,  21],
#         [115, 115],
#         ...,
#         [  9,   1],
#         [752,   1],
#         [  2,   1]], device='cuda:0')
# tensor([0., 1.], device='cuda:0')
#
# =====
#
# ['33', '278']
# tensor([[  2,   2],
#         [ 21,  42],
#         [115, 500],
#         ...,
#         [  1,   9],
#         [  1, 752],
#         [  1,   2]], device='cuda:0')
# tensor([1., 0.], device='cuda:0')
#
# =====
#
# ['284', '553']
# tensor([[  2,   2],
#         [ 42,  42],
#         [500, 500],
#         ...,
#         [  1,   9],
#         [  1, 752],
#         [  1,   2]], device='cuda:0')
# tensor([1., 0.], device='cuda:0')
#
# =====
#
# ['123', '535']
# tensor([[  2,   2],
#         [ 21,  42],
#         [115, 500],
#         ...,
#         [  9,   1],
#         [752,   1],
#         [  2,   1]], device='cuda:0')
# tensor([1., 1.], device='cuda:0')
#
# =====
#
# ['421', '479']
# tensor([[  2,   2],
#         [ 42,  42],
#         [500, 500],
#         ...,
#         [  1,   9],
#         [  1, 752],
#         [  1,   2]], device='cuda:0')
# tensor([1., 0.], device='cuda:0')
#
# =====
#
# ['298', '60']
# tensor([[  2,   2],
#         [ 42,  21],
#         [500, 115],
#         ...,
#         [  9,   1],
#         [752,   1],
#         [  2,   1]], device='cuda:0')
# tensor([0., 1.], device='cuda:0')
#
# =====
#
# ['111', '382']
# tensor([[  2,   2],
#         [ 42,  42],
#         [500, 500],
#         ...,
#         [  1,   9],
#         [  1, 752],
#         [  1,   2]], device='cuda:0')
# tensor([1., 1.], device='cuda:0')
#
# =====
#
# ['209', '152']
# tensor([[  2,   2],
#         [ 42,  21],
#         [500, 115],
#         ...,
#         [  9,   1],
#         [752,   1],
#         [  2,   1]], device='cuda:0')
# tensor([1., 0.], device='cuda:0')
#
# =====
#
# ['93', '147']
# tensor([[  2,   2],
#         [ 21,  42],
#         [115, 500],
#         ...,
#         [  9,   1],
#         [752,   1],
#         [  2,   1]], device='cuda:0')
# tensor([0., 1.], device='cuda:0')
#
# =====
#
# ['409', '235']
# tensor([[  2,   2],
#         [ 42,  21],
#         [500, 115],
#         ...,
#         [  9,   1],
#         [752,   1],
#         [  2,   1]], device='cuda:0')
# tensor([1., 1.], device='cuda:0')
#
# =====
#
# ['512', '210']
# tensor([[  2,   2],
#         [ 42,  21],
#         [500, 115],
#         ...,
#         [  1,   9],
#         [  1, 752],
#         [  1,   2]], device='cuda:0')
# tensor([1., 1.], device='cuda:0')
#
# =====
#
# ['157', '37']
# tensor([[  2,   2],
#         [ 42,  21],
#         [500, 115],
#         ...,
#         [  9,   1],
#         [752,   1],
#         [  2,   1]], device='cuda:0')
# tensor([0., 0.], device='cuda:0')
#
# =====
#
# ['355', '311']
# tensor([[  2,   2],
#         [ 42,  42],
#         [500,  60],
#         ...,
#         [  9,   1],
#         [752,   1],
#         [  2,   1]], device='cuda:0')
# tensor([0., 0.], device='cuda:0')
#
# =====
#
# ['18', '388']
# tensor([[  2,   2],
#         [ 21,  42],
#         [115, 500],
#         ...,
#         [  9,   1],
#         [752,   1],
#         [  2,   1]], device='cuda:0')
# tensor([1., 0.], device='cuda:0')
#
# =====
#
# ['139', '204']
# tensor([[  2,   2],
#         [ 42,  42],
#         [500, 500],
#         ...,
#         [  9,   1],
#         [752,   1],
#         [  2,   1]], device='cuda:0')
# tensor([0., 1.], device='cuda:0')
#
# =====
#
# ['419', '181']
# tensor([[  2,   2],
#         [ 21,  21],
#         [115, 115],
#         ...,
#         [  9,   1],
#         [752,   1],
#         [  2,   1]], device='cuda:0')
# tensor([1., 0.], device='cuda:0')
#
# =====
#
# ['496', '579']
# tensor([[  2,   2],
#         [ 42,  42],
#         [500, 500],
#         ...,
#         [  9,   1],
#         [752,   1],
#         [  2,   1]], device='cuda:0')
# tensor([0., 0.], device='cuda:0')
#
# =====
#
# ['388', '57']
# tensor([[  2,   2],
#         [ 42,  42],
#         [500, 500],
#         ...,
#         [  1,   9],
#         [  1, 752],
#         [  1,   2]], device='cuda:0')
# tensor([0., 1.], device='cuda:0')
#
# =====
#
# ['167', '428']
# tensor([[  2,   2],
#         [ 21,  42],
#         [115, 500],
#         ...,
#         [  9,   1],
#         [752,   1],
#         [  2,   1]], device='cuda:0')
# tensor([0., 1.], device='cuda:0')
#
# =====
#
# ['248', '371']
# tensor([[  2,   2],
#         [ 21,  42],
#         [115, 500],
#         ...,
#         [  9,   1],
#         [752,   1],
#         [  2,   1]], device='cuda:0')
# tensor([0., 0.], device='cuda:0')
#
# =====
#
# ['297', '45']
# tensor([[  2,   2],
#         [ 42,  21],
#         [500, 115],
#         ...,
#         [  1,   9],
#         [  1, 752],
#         [  1,   2]], device='cuda:0')
# tensor([0., 1.], device='cuda:0')
#
# =====
#
# ['341', '117']
# tensor([[  2,   2],
#         [ 42,  42],
#         [500, 500],
#         ...,
#         [  9,   1],
#         [752,   1],
#         [  2,   1]], device='cuda:0')
# tensor([1., 1.], device='cuda:0')
#
# =====
#
# ['212', '145']
# tensor([[  2,   2],
#         [ 42,  21],
#         [500, 115],
#         ...,
#         [  9,   1],
#         [752,   1],
#         [  2,   1]], device='cuda:0')
# tensor([1., 0.], device='cuda:0')
#
# =====
#
# ['547', '149']
# tensor([[  2,   2],
#         [ 42,  42],
#         [500, 500],
#         ...,
#         [  1,   9],
#         [  1, 752],
#         [  1,   2]], device='cuda:0')
# tensor([0., 1.], device='cuda:0')
#
# =====
#
# ['383', '9']
# tensor([[  2,   2],
#         [ 42,  21],
#         [500, 115],
#         ...,
#         [  1,   9],
#         [  1, 752],
#         [  1,   2]], device='cuda:0')
# tensor([0., 1.], device='cuda:0')
#
# =====
#
# ['482', '281']
# tensor([[  2,   2],
#         [ 42,  42],
#         [500, 500],
#         ...,
#         [  9,   1],
#         [752,   1],
#         [  2,   1]], device='cuda:0')
# tensor([1., 0.], device='cuda:0')
#
# =====
#
# ['520', '280']
# tensor([[  2,   2],
#         [ 42,  42],
#         [500, 500],
#         ...,
#         [  9,   1],
#         [752,   1],
#         [  2,   1]], device='cuda:0')
# tensor([1., 1.], device='cuda:0')
#
# =====
#
# ['432', '579']
# tensor([[  2,   2],
#         [ 42,  42],
#         [500, 500],
#         ...,
#         [  1,   9],
#         [  1, 752],
#         [  1,   2]], device='cuda:0')
# tensor([1., 0.], device='cuda:0')
#
# =====
#
# ['289', '180']
# tensor([[  2,   2],
#         [ 21,  21],
#         [115, 115],
#         ...,
#         [  9,   1],
#         [752,   1],
#         [  2,   1]], device='cuda:0')
# tensor([1., 1.], device='cuda:0')
#
# =====
#
# ['321', '77']
# tensor([[  2,   2],
#         [ 21,  21],
#         [115, 115],
#         ...,
#         [172,   1],
#         [ 13,   1],
#         [  2,   1]], device='cuda:0')
# tensor([1., 1.], device='cuda:0')
#
# =====
#
# ['355', '140']
# tensor([[  2,   2],
#         [ 42,  21],
#         [500, 115],
#         ...,
#         [  9,   1],
#         [752,   1],
#         [  2,   1]], device='cuda:0')
# tensor([0., 1.], device='cuda:0')
#
# =====
#
# ['2', '547']
# tensor([[  2,   2],
#         [ 21,  42],
#         [115, 500],
#         ...,
#         [  9,   1],
#         [752,   1],
#         [  2,   1]], device='cuda:0')
# tensor([1., 0.], device='cuda:0')
#
# =====
#
# ['92', '585']
# tensor([[  2,   2],
#         [ 42,  42],
#         [500, 500],
#         ...,
#         [  1,   9],
#         [  1, 752],
#         [  1,   2]], device='cuda:0')
# tensor([0., 1.], device='cuda:0')
#
# =====
#
# ['36', '465']
# tensor([[  2,   2],
#         [ 21,  42],
#         [115, 500],
#         ...,
#         [  1,   9],
#         [  1, 752],
#         [  1,   2]], device='cuda:0')
# tensor([0., 0.], device='cuda:0')
#
# =====
#
# ['559', '255']
# tensor([[  2,   2],
#         [ 42,  42],
#         [500, 500],
#         ...,
#         [  9,   1],
#         [752,   1],
#         [  2,   1]], device='cuda:0')
# tensor([0., 1.], device='cuda:0')
#
# =====
#
# ['329', '365']
# tensor([[  2,   2],
#         [ 42,  42],
#         [500, 500],
#         ...,
#         [  9,   1],
#         [752,   1],
#         [  2,   1]], device='cuda:0')
# tensor([0., 0.], device='cuda:0')
#
# =====
#
# ['506', '396']
# tensor([[  2,   2],
#         [ 42,  42],
#         [500, 500],
#         ...,
#         [  9,   1],
#         [752,   1],
#         [  2,   1]], device='cuda:0')
# tensor([1., 0.], device='cuda:0')
#
# =====
#
# ['505', '349']
# tensor([[  2,   2],
#         [ 42,  42],
#         [500, 500],
#         ...,
#         [  9,   1],
#         [752,   1],
#         [  2,   1]], device='cuda:0')
# tensor([0., 0.], device='cuda:0')
#
# =====
#
# ['144', '271']
# tensor([[  2,   2],
#         [ 42,  21],
#         [500, 115],
#         ...,
#         [  1,   9],
#         [  1, 752],
#         [  1,   2]], device='cuda:0')
# tensor([0., 0.], device='cuda:0')
#
# =====
#
# ['439', '465']
# tensor([[  2,   2],
#         [ 42,  42],
#         [500, 500],
#         ...,
#         [  1,   9],
#         [  1, 752],
#         [  1,   2]], device='cuda:0')
# tensor([1., 0.], device='cuda:0')
#
# =====
#
# ['137', '595']
# tensor([[  2,   2],
#         [ 42,  42],
#         [500, 500],
#         ...,
#         [  1,   9],
#         [  1, 752],
#         [  1,   2]], device='cuda:0')
# tensor([0., 0.], device='cuda:0')
#
# =====
#
# ['402', '370']
# tensor([[  2,   2],
#         [ 42,  42],
#         [500, 500],
#         ...,
#         [  9,   1],
#         [752,   1],
#         [  2,   1]], device='cuda:0')
# tensor([0., 1.], device='cuda:0')
#
# =====
#
# ['396', '150']
# tensor([[  2,   2],
#         [ 42,  42],
#         [500, 500],
#         ...,
#         [  1,   9],
#         [  1, 752],
#         [  1,   2]], device='cuda:0')
# tensor([0., 1.], device='cuda:0')
#
# =====
#
# ['309', '253']
# tensor([[  2,   2],
#         [ 42,  42],
#         [500, 500],
#         ...,
#         [  1,   9],
#         [  1, 752],
#         [  1,   2]], device='cuda:0')
# tensor([0., 0.], device='cuda:0')
#
# =====
#
# ['416', '275']
# tensor([[  2,   2],
#         [ 42,  42],
#         [500, 500],
#         ...,
#         [  9,   1],
#         [752,   1],
#         [  2,   1]], device='cuda:0')
# tensor([0., 1.], device='cuda:0')
#
# =====
#
# ['3', '75']
# tensor([[  2,   2],
#         [ 21,  21],
#         [115, 115],
#         ...,
#         [  9,   1],
#         [752,   1],
#         [  2,   1]], device='cuda:0')
# tensor([1., 1.], device='cuda:0')
#
# =====
#
# ['502', '329']
# tensor([[  2,   2],
#         [ 42,  42],
#         [500, 500],
#         ...,
#         [  1,   9],
#         [  1, 752],
#         [  1,   2]], device='cuda:0')
# tensor([1., 0.], device='cuda:0')
#
# =====
#
# ['15', '302']
# tensor([[  2,   2],
#         [ 21,  42],
#         [115, 500],
#         ...,
#         [390,   1],
#         [419,   1],
#         [  2,   1]], device='cuda:0')
# tensor([0., 1.], device='cuda:0')
#
# =====
#
# ['22', '176']
# tensor([[  2,   2],
#         [ 21,  42],
#         [115, 500],
#         ...,
#         [  1,   9],
#         [  1, 752],
#         [  1,   2]], device='cuda:0')
# tensor([1., 0.], device='cuda:0')
#
# =====
#
# ['94', '426']
# tensor([[  2,   2],
#         [ 42,  21],
#         [500, 115],
#         ...,
#         [  9,   1],
#         [752,   1],
#         [  2,   1]], device='cuda:0')
# tensor([1., 1.], device='cuda:0')
#
# =====
#
# ['561', '534']
# tensor([[  2,   2],
#         [ 21,  42],
#         [115, 500],
#         ...,
#         [  9,   1],
#         [752,   1],
#         [  2,   1]], device='cuda:0')
# tensor([0., 0.], device='cuda:0')
#
# =====
#
# ['325', '86']
# tensor([[   2,    2],
#         [  42,   42],
#         [ 500,  500],
#         ...,
#         [ 752,    1],
#         [1639,    1],
#         [   2,    1]], device='cuda:0')
# tensor([1., 0.], device='cuda:0')
#
# =====
#
# ['375', '253']
# tensor([[  2,   2],
#         [ 42,  42],
#         [500, 500],
#         ...,
#         [  9,   1],
#         [752,   1],
#         [  2,   1]], device='cuda:0')
# tensor([0., 0.], device='cuda:0')
#
# =====
#
# ['467', '274']
# tensor([[  2,   2],
#         [ 21,  21],
#         [115, 115],
#         ...,
#         [  9,   1],
#         [752,   1],
#         [  2,   1]], device='cuda:0')
# tensor([1., 1.], device='cuda:0')
#
# =====
#
# ['536', '16']
# tensor([[  2,   2],
#         [ 42,  21],
#         [500, 115],
#         ...,
#         [  9,   1],
#         [752,   1],
#         [  2,   1]], device='cuda:0')
# tensor([0., 0.], device='cuda:0')
#
# =====
#
# ['110', '383']
# tensor([[  2,   2],
#         [ 42,  42],
#         [500, 500],
#         ...,
#         [  9,   1],
#         [752,   1],
#         [  2,   1]], device='cuda:0')
# tensor([1., 0.], device='cuda:0')
#
# =====
#
# ['529', '447']
# tensor([[  2,   2],
#         [ 42,  42],
#         [500, 500],
#         ...,
#         [  9,   1],
#         [752,   1],
#         [  2,   1]], device='cuda:0')
# tensor([1., 1.], device='cuda:0')
#
# =====
#
# ['184', '16']
# tensor([[  2,   2],
#         [ 42,  21],
#         [500, 115],
#         ...,
#         [  9,   1],
#         [752,   1],
#         [  2,   1]], device='cuda:0')
# tensor([0., 0.], device='cuda:0')
#
# =====
#
# ['264', '74']
# tensor([[  2,   2],
#         [ 42,  21],
#         [500, 115],
#         ...,
#         [  9,   1],
#         [752,   1],
#         [  2,   1]], device='cuda:0')
# tensor([0., 1.], device='cuda:0')
#
# =====
#
# ['118', '567']
# tensor([[  2,   2],
#         [ 21,  42],
#         [115, 500],
#         ...,
#         [  1,   9],
#         [  1, 752],
#         [  1,   2]], device='cuda:0')
# tensor([0., 1.], device='cuda:0')
#
# =====
#
# ['261', '124']
# tensor([[  2,   2],
#         [ 21,  21],
#         [115, 115],
#         ...,
#         [  9,   1],
#         [752,   1],
#         [  2,   1]], device='cuda:0')
# tensor([0., 0.], device='cuda:0')
#
# =====
#
# ['263', '304']
# tensor([[  2,   2],
#         [ 21,  42],
#         [115, 500],
#         ...,
#         [  9,   1],
#         [752,   1],
#         [  2,   1]], device='cuda:0')
# tensor([1., 0.], device='cuda:0')
#
# =====
#
# ['332', '349']
# tensor([[  2,   2],
#         [ 42,  42],
#         [500, 500],
#         ...,
#         [  1,   9],
#         [  1, 752],
#         [  1,   2]], device='cuda:0')
# tensor([1., 0.], device='cuda:0')
#
# =====
#
# ['249', '108']
# tensor([[  2,   2],
#         [ 21,  21],
#         [115, 115],
#         ...,
#         [  9,   1],
#         [752,   1],
#         [  2,   1]], device='cuda:0')
# tensor([0., 1.], device='cuda:0')
#
# =====
#
# ['375', '554']
# tensor([[  2,   2],
#         [ 42,  42],
#         [500, 500],
#         ...,
#         [  9,   1],
#         [752,   1],
#         [  2,   1]], device='cuda:0')
# tensor([0., 0.], device='cuda:0')
#
# =====
#
# ['49', '244']
# tensor([[  2,   2],
#         [ 21,  42],
#         [115, 500],
#         ...,
#         [  1,   9],
#         [  1, 752],
#         [  1,   2]], device='cuda:0')
# tensor([1., 1.], device='cuda:0')
#
# =====
#
# ['198', '431']
# tensor([[  2,   2],
#         [ 42,  21],
#         [500, 115],
#         ...,
#         [  1,   9],
#         [  1, 752],
#         [  1,   2]], device='cuda:0')
# tensor([1., 1.], device='cuda:0')
#
# =====
#
# ['528', '116']
# tensor([[  2,   2],
#         [ 42,  42],
#         [500, 500],
#         ...,
#         [  1,   9],
#         [  1, 752],
#         [  1,   2]], device='cuda:0')
# tensor([1., 1.], device='cuda:0')
#
# =====
#
# ['83', '360']
# tensor([[  2,   2],
#         [ 42,  42],
#         [500, 500],
#         ...,
#         [  1,   9],
#         [  1, 752],
#         [  1,   2]], device='cuda:0')
# tensor([1., 0.], device='cuda:0')
#
# =====
#
# ['500', '304']
# tensor([[  2,   2],
#         [ 42,  42],
#         [500, 500],
#         ...,
#         [  9,   1],
#         [752,   1],
#         [  2,   1]], device='cuda:0')
# tensor([1., 0.], device='cuda:0')
#
# =====
#
# ['59', '338']
# tensor([[  2,   2],
#         [ 21,  42],
#         [115, 500],
#         ...,
#         [  1,   9],
#         [  1, 752],
#         [  1,   2]], device='cuda:0')
# tensor([1., 1.], device='cuda:0')
#
# =====
#
# ['76', '543']
# tensor([[  2,   2],
#         [ 21,  42],
#         [115, 500],
#         ...,
#         [  1,   9],
#         [  1, 752],
#         [  1,   2]], device='cuda:0')
# tensor([1., 1.], device='cuda:0')
#
# =====
#
# ['566', '307']
# tensor([[  2,   2],
#         [ 42,  42],
#         [500, 500],
#         ...,
#         [  1,   9],
#         [  1, 752],
#         [  1,   2]], device='cuda:0')
# tensor([1., 1.], device='cuda:0')
#
# =====
#
# ['547', '10']
# tensor([[  2,   2],
#         [ 42,  21],
#         [500, 115],
#         ...,
#         [  9,   1],
#         [752,   1],
#         [  2,   1]], device='cuda:0')
# tensor([0., 1.], device='cuda:0')
#
# =====
#
# ['336', '192']
# tensor([[  2,   2],
#         [ 42,  42],
#         [500, 500],
#         ...,
#         [  1,   9],
#         [  1, 752],
#         [  1,   2]], device='cuda:0')
# tensor([0., 1.], device='cuda:0')
#
# =====
#
# ['196', '176']
# tensor([[  2,   2],
#         [ 42,  42],
#         [500, 500],
#         ...,
#         [  1,   9],
#         [  1, 752],
#         [  1,   2]], device='cuda:0')
# tensor([0., 0.], device='cuda:0')
#
# =====
#
# ['234', '50']
# tensor([[  2,   2],
#         [ 21,  21],
#         [115, 115],
#         ...,
#         [  9,   1],
#         [752,   1],
#         [  2,   1]], device='cuda:0')
# tensor([1., 0.], device='cuda:0')
#
# =====
#
# ['588', '442']
# tensor([[  2,   2],
#         [ 42,  21],
#         [500, 115],
#         ...,
#         [  1,   9],
#         [  1, 752],
#         [  1,   2]], device='cuda:0')
# tensor([1., 1.], device='cuda:0')
#
# End of demo

# %%
print("The size of this vocabulary is {}".format(len(TEXT.vocab)))
# !ls
# Out:
# The size of this vocabulary is 4578
# drive  sample_data

# %%
print(f'Number of training examples: {len(train_iter)}')
# Out:
# Number of training examples: 227

# %% [markdown]
# Again, we'll view how many examples are in each split.

# %%
print(f'Number of training examples: {len(train_iter)}')
print(f'Number of validation examples: {len(valid_iter)}')
print(f'Number of testing examples: {len(test_iter)}')
# Out:
# Number of training examples: 227
# Number of validation examples: 82
# Number of testing examples: 72

# %%
print(f"Unique tokens in TEXT vocabulary: {len(TEXT.vocab)}")
print(f"Unique tokens in LABEL vocabulary: {len(LABEL.vocab)}")
# Out:
# Unique tokens in TEXT vocabulary: 4578
# Unique tokens in LABEL vocabulary: 2

# %%
print(TEXT.vocab.freqs.most_common(20))
# Out:
# [('the', 313375), ('that', 165361), ('to', 142242), ('of', 111527), ('and', 110603), ('a', 104173), ('is', 97071), ('in', 87910), ('it', 72871), ('i', 70492), ('you', 66947), ('this', 45852), ('not', 41830), ('have', 37049), ('be', 34691), ('but', 34654), ('if', 33050), ('what', 32345), ('we', 31433), ('was', 30999)]

# %%
print(TEXT.vocab.itos[:10])
# Out:
# ['<unk>', '<pad>', '', 'the', 'that', 'to', 'of', 'and', 'a', 'is']

# %% [markdown]
# Below is a simple implementation of an RNN. Thanks to Ben Trevett's tutorial on sentiment analysis with RNNs for the guidance here. https://github.com/bentrevett/pytorch-sentiment-analysis

# %%
import torch.nn as nn

class RNN(nn.Module):
    def __init__(self, input_dim, embedding_dim, hidden_dim, output_dim):
        
        super().__init__()
        
        self.embedding = nn.Embedding(input_dim, embedding_dim)
        
        self.rnn = nn.RNN(embedding_dim, hidden_dim)
        
        self.fc = nn.Linear(hidden_dim, output_dim)
        
    def forward(self, text):

        #text = [sent len, batch size]
        
        embedded = self.embedding(text)
        
        #embedded = [sent len, batch size, emb dim]
        
        output, hidden = self.rnn(embedded)
        
        #output = [sent len, batch size, hid dim]
        #hidden = [1, batch size, hid dim]
        
        assert torch.equal(output[-1,:,:], hidden.squeeze(0))
        
        return self.fc(hidden.squeeze(0))

# %% [markdown]
# We now create an instance of our RNN class.
#
# The input dimension is the dimension of the one-hot vectors, which is equal to the vocabulary size.
#
# The embedding dimension is the size of the dense word vectors. This is usually around 50-250 dimensions, but depends on the size of the vocabulary.
#
# The hidden dimension is the size of the hidden states. This is usually around 100-500 dimensions, but also depends on factors such as on the vocabulary size, the size of the dense vectors and the complexity of the task.
#
# The output dimension is usually the number of classes, however in the case of only 2 classes the output value is between 0 and 1 and thus can be 1-dimensional, i.e. a single scalar real number.

# %%
INPUT_DIM = len(TEXT.vocab)
EMBEDDING_DIM = 100
HIDDEN_DIM = 256
OUTPUT_DIM = 1

model = RNN(INPUT_DIM, EMBEDDING_DIM, HIDDEN_DIM, OUTPUT_DIM)

# %%
def count_parameters(model):
  '''
  Function to count the number of parameters in a model.
  '''
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

print(f'The model has {count_parameters(model):,} trainable parameters')
# Out:
# The model has 549,705 trainable parameters

# %% [markdown]
# ## Train the Model

# %%
import torch.optim as optim

optimizer = optim.SGD(model.parameters(), lr=1e-3)

# %%
criterion = nn.BCEWithLogitsLoss()

# %%
model = model.to(device)
criterion = criterion.to(device)

# %%
def binary_accuracy(preds, y):
    """
    Returns accuracy per batch, i.e. if you get 8/10 right, this returns 0.8, NOT 8
    """

    #round predictions to the closest integer
    rounded_preds = torch.round(torch.sigmoid(preds))
    correct = (rounded_preds == y).float() #convert into float for division 
    acc = correct.sum() / len(correct)
    return acc

# %%
def train(model, iterator, optimizer, criterion):
  '''
  Train the model.
  '''
    
    epoch_loss = 0
    epoch_acc = 0
    
    model.train()
    
    for batch in iterator:
        
        optimizer.zero_grad()
                
        predictions = model(batch.text).squeeze(1)
        
        loss = criterion(predictions, batch.label)
        
        acc = binary_accuracy(predictions, batch.label)
        
        loss.backward()
        
        optimizer.step()
        
        epoch_loss += loss.item()
        epoch_acc += acc.item()
        
    return epoch_loss / len(iterator), epoch_acc / len(iterator)

# %%
def evaluate(model, iterator, criterion):
    
    epoch_loss = 0
    epoch_acc = 0
    
    model.eval()
    
    with torch.no_grad():
    
        for batch in iterator:

            predictions = model(batch.text).squeeze(1)
            
            loss = criterion(predictions, batch.label)
            
            acc = binary_accuracy(predictions, batch.label)

            epoch_loss += loss.item()
            epoch_acc += acc.item()
        
    return epoch_loss / len(iterator), epoch_acc / len(iterator)

# %%
import time

def epoch_time(start_time, end_time):
  '''
  Measure epoch training time
  '''
    elapsed_time = end_time - start_time
    elapsed_mins = int(elapsed_time / 60)
    elapsed_secs = int(elapsed_time - (elapsed_mins * 60))
    return elapsed_mins, elapsed_secs

# %%
N_EPOCHS = 5

best_valid_loss = float('inf')

for epoch in range(N_EPOCHS):

    start_time = time.time()
    
    train_loss, train_acc = train(model, train_iter, optimizer, criterion)
    valid_loss, valid_acc = evaluate(model, valid_iter, criterion)
    
    end_time = time.time()

    epoch_mins, epoch_secs = epoch_time(start_time, end_time)
    
    if valid_loss < best_valid_loss:
        best_valid_loss = valid_loss
        torch.save(model.state_dict(), 'tut1-model.pt')
    
    print(f'Epoch: {epoch+1:02} | Epoch Time: {epoch_mins}m {epoch_secs}s')
    print(f'\tTrain Loss: {train_loss:.3f} | Train Acc: {train_acc*100:.2f}%')
    print(f'\t Val. Loss: {valid_loss:.3f} |  Val. Acc: {valid_acc*100:.2f}%')
# Out:
# Epoch: 01 | Epoch Time: 1m 30s
# 	Train Loss: 0.696 | Train Acc: 52.86%
# 	 Val. Loss: 0.705 |  Val. Acc: 45.12%
# Epoch: 02 | Epoch Time: 1m 30s
# 	Train Loss: 0.697 | Train Acc: 49.12%
# 	 Val. Loss: 0.695 |  Val. Acc: 50.61%
# Epoch: 03 | Epoch Time: 1m 30s
# 	Train Loss: 0.694 | Train Acc: 51.98%
# 	 Val. Loss: 0.706 |  Val. Acc: 43.90%
# Epoch: 04 | Epoch Time: 1m 30s
# 	Train Loss: 0.697 | Train Acc: 48.68%
# 	 Val. Loss: 0.695 |  Val. Acc: 50.61%
# Epoch: 05 | Epoch Time: 1m 30s
# 	Train Loss: 0.696 | Train Acc: 51.32%
# 	 Val. Loss: 0.701 |  Val. Acc: 45.73%

# %%
model.load_state_dict(torch.load('tut1-model.pt'))

test_loss, test_acc = evaluate(model, test_iter, criterion)

print(f'Test Loss: {test_loss:.3f} | Test Acc: {test_acc*100:.2f}%')
# Out:
# Test Loss: 0.691 | Test Acc: 51.39%

# %%
model
# Out:
# RNN(
#   (embedding): Embedding(4578, 100)
#   (rnn): RNN(100, 256)
#   (fc): Linear(in_features=256, out_features=1, bias=True)
# )
